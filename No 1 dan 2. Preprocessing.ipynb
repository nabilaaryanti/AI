# %%
# Import modul
import pandas as pd
import os
os.chdir('C:/Users/DEBBY ROBIYANTI/AI/NLP')

# %%
from NLP_Models import TextMining as tm
from NLP_Models import CleanText as ct

# %% [markdown]
# ### Data Hate Speech

# %%
#HATESPEECH
dataPath = tm.crawlFiles('./NLP_Models/data/HATE SPEECH/Hate Speech/', types = 'json')

# %%
data = pd.concat([pd.read_json(f, lines=True) for f in dataPath])

# %%
data = data[['created_at', 'date', 'time', \
             'user_id', 'username', 'name',\
                 'tweet','mentions', 'urls', 'photos', 'replies_count', \
                     'retweets_count', 'likes_count', 'hashtags',\
                         'link', 'retweet', 'quote_url',\
                             'near', 'geo', 'source', 'user_rt_id', 'user_rt',\
                                 'retweet_id', 'reply_to', 'retweet_date']]

# %%
data['Label'] = '-1'
# Keterangan : data hate = -1 dan data non hate =1

# %%
N, P = data.shape
'baris = ', N, ', Kolom = ', P
# Out:
# ('baris = ', 8118, ', Kolom = ', 26)

# %%
data.head()
# Out:
#                                   created_at       date      time  \
# 0  2021-06-04 11:23:52 SE Asia Standard Time 2021-06-04  11:23:52
# 1  2021-06-04 09:24:21 SE Asia Standard Time 2021-06-04  09:24:21
# 2  2021-06-04 08:53:53 SE Asia Standard Time 2021-06-04  08:53:53
# 3  2021-06-04 08:43:41 SE Asia Standard Time 2021-06-04  08:43:41
# 4  2021-06-04 08:40:51 SE Asia Standard Time 2021-06-04  08:40:51
#
#                user_id       username                name  \
# 0   980982152786427904  dhejan_alfa13       dhejan alfa77
# 1  1291974491547922434   ayah__hanita  🇲🇨Buzzer_NKRI✊🇲🇨❤️
# 2  1334180999194767362      cyberkn__        Cyber KN16H7
# 3  1334180999194767362      cyberkn__        Cyber KN16H7
# 4  1397542615919128578    erwinshah19          Erwin Shah
#
#                                                tweet mentions urls  \
# 0  @Taufik06644475 @tijabar Nah ini tolol yg bole...       []   []
# 1  Biar SETAN, KADRUN, Politikus Busuk &amp; Peng...       []   []
# 2  @dahlia93362963 @Abu_Ar_Rayyan @SukurWong @Neg...       []   []
# 3  😂 bipang of the year udah tolol permanen ngeye...       []   []
# 4  @GoblokKadrun @Herlin_673YP @Ari3Pras @Ferdina...       []   []
#
#                                               photos  ...  \
# 0                                                 []  ...
# 1  [https://pbs.twimg.com/media/E3ASOpvVoAIE6UI.jpg]  ...
# 2                                                 []  ...
# 3                                                 []  ...
# 4  [https://pbs.twimg.com/media/E3AIRmZVIAQJigD.jpg]  ...
#
#                                            quote_url  near  geo source  \
# 0
# 1
# 2
# 3  https://twitter.com/Abu_Ar_Rayyan/status/14005...
# 4
#
#   user_rt_id  user_rt retweet_id  \
# 0
# 1
# 2
# 3
# 4
#
#                                             reply_to retweet_date Label
# 0  [{'screen_name': 'Taufik06644475', 'name': 'Ta...                 -1
# 1                                                 []                 -1
# 2  [{'screen_name': 'dahlia93362963', 'name': 'da...                 -1
# 3                                                 []                 -1
# 4  [{'screen_name': 'GoblokKadrun', 'name': 'Kadr...                 -1
#
# [5 rows x 26 columns]

# %%
data.to_json('./NLP_Models/data/dataHate.json', orient='records')

# %% [markdown]
# ### Data Non Hate Speech

# %%
#NON HATESPEECH  
dataPathnhs = tm.crawlFiles('./NLP_Models/data/HATE SPEECH/Non Hate Speech/', types = 'json')

# %%
datanhs = pd.concat([pd.read_json(f, lines=True) for f in dataPathnhs])

# %%
datanhs = datanhs[['created_at', 'date', 'time', \
             'user_id', 'username', 'name',\
                 'tweet','mentions', 'urls', 'photos', 'replies_count', \
                     'retweets_count', 'likes_count', 'hashtags',\
                         'link', 'retweet', 'quote_url',\
                             'near', 'geo', 'source', 'user_rt_id', 'user_rt',\
                                 'retweet_id', 'reply_to', 'retweet_date']]

# %%
datanhs['Label'] = '1'
# Keterangan : data hate = -1 dan data non hate = 1

# %%
N, P = datanhs.shape
'baris = ', N, ', Kolom = ', P
# Out:
# ('baris = ', 6700, ', Kolom = ', 26)

# %%
datanhs.head()
# Out:
#                                   created_at       date      time  \
# 0  2021-06-05 22:05:27 SE Asia Standard Time 2021-06-05  22:05:27
# 1  2021-06-05 21:29:34 SE Asia Standard Time 2021-06-05  21:29:34
# 2  2021-06-05 20:32:03 SE Asia Standard Time 2021-06-05  20:32:03
# 3  2021-06-05 19:32:58 SE Asia Standard Time 2021-06-05  19:32:58
# 4  2021-06-05 19:31:44 SE Asia Standard Time 2021-06-05  19:31:44
#
#                user_id      username                   name  \
# 0  1331851918998532096       nuchano                nurul ✰
# 1  1268646569907118080        c7hl94                   njaa
# 2  1223648728877191168      kysya041  Kaiko_chi04🍵🧁 - キレイサカ
# 3  1378447450596249602   kangjoonmin          Kang Joon-min
# 4            738699002  kevin_gotama       Kevin Gotama 吴信杰
#
#                                                tweet  \
# 0  @aurumstay @schfess semangat yaa key!! 😆💗 semo...
# 1  apa yg buat gw kek gini, gw cerita walaupun it...
# 2  @zahraaysha_ Huhuhu.. iya, aku cuma kurang mot...
# 3  @schfess Tetap semangat 🔥. Aku juga dulu pas p...
# 4  Aku ada pantun buat @gabyJKT48                ...
#
#                                             mentions urls  \
# 0                                                 []   []
# 1                                                 []   []
# 2                                                 []   []
# 3                                                 []   []
# 4  [{'screen_name': 'gabyjkt48', 'name': 'gabriel...   []
#
#                                               photos  ...  quote_url  near  \
# 0  [https://pbs.twimg.com/tweet_video_thumb/E3IKA...  ...
# 1                                                 []  ...
# 2                                                 []  ...
# 3                                                 []  ...
# 4                                                 []  ...
#
#    geo source user_rt_id  user_rt retweet_id  \
# 0
# 1
# 2
# 3
# 4
#
#                                             reply_to retweet_date Label
# 0  [{'screen_name': 'aurumstay', 'name': 'Keiynni...                  1
# 1                                                 []                  1
# 2  [{'screen_name': 'zahraaysha_', 'name': 'Safin...                  1
# 3  [{'screen_name': 'schfess', 'name': 'SCHFESS',...                  1
# 4                                                 []                  1
#
# [5 rows x 26 columns]

# %%
datanhs.to_json('./NLP_Models/data/dataNonHate.json', orient='records')

# %% [markdown]
# ### Data Final

# %%
dataFinal = pd.concat([data, datanhs])

# %%
dataFinal = dataFinal.reset_index(drop= True)

# %%
dataFinal
# Out:
#                                       created_at       date      time  \
# 0      2021-06-04 11:23:52 SE Asia Standard Time 2021-06-04  11:23:52
# 1      2021-06-04 09:24:21 SE Asia Standard Time 2021-06-04  09:24:21
# 2      2021-06-04 08:53:53 SE Asia Standard Time 2021-06-04  08:53:53
# 3      2021-06-04 08:43:41 SE Asia Standard Time 2021-06-04  08:43:41
# 4      2021-06-04 08:40:51 SE Asia Standard Time 2021-06-04  08:40:51
# ...                                          ...        ...       ...
# 14813  2021-06-05 21:50:53 SE Asia Standard Time 2021-06-05  21:50:53
# 14814  2021-06-05 21:50:34 SE Asia Standard Time 2021-06-05  21:50:34
# 14815  2021-06-05 21:49:10 SE Asia Standard Time 2021-06-05  21:49:10
# 14816  2021-06-05 21:48:59 SE Asia Standard Time 2021-06-05  21:48:59
# 14817  2021-06-05 21:48:39 SE Asia Standard Time 2021-06-05  21:48:39
#
#                    user_id       username                name  \
# 0       980982152786427904  dhejan_alfa13       dhejan alfa77
# 1      1291974491547922434   ayah__hanita  🇲🇨Buzzer_NKRI✊🇲🇨❤️
# 2      1334180999194767362      cyberkn__        Cyber KN16H7
# 3      1334180999194767362      cyberkn__        Cyber KN16H7
# 4      1397542615919128578    erwinshah19          Erwin Shah
# ...                    ...            ...                 ...
# 14813  1400660331634970628       sukasunu        kim kaykay !
# 14814  1355888428320079878      daaaayaa_                   ♡
# 14815           2353288471   febiano_1109  Febiano Nya Ce Fio
# 14816            257001172     luluhusnaa              Luluvs
# 14817  1323255029172563970        niwaskr            Niwawa 🥭
#
#                                                    tweet mentions urls  \
# 0      @Taufik06644475 @tijabar Nah ini tolol yg bole...       []   []
# 1      Biar SETAN, KADRUN, Politikus Busuk &amp; Peng...       []   []
# 2      @dahlia93362963 @Abu_Ar_Rayyan @SukurWong @Neg...       []   []
# 3      😂 bipang of the year udah tolol permanen ngeye...       []   []
# 4      @GoblokKadrun @Herlin_673YP @Ari3Pras @Ferdina...       []   []
# ...                                                  ...      ...  ...
# 14813  SERU BANGET GANGGUIN MIRAE SAMA JYUBI PAKE GIF 😏😏       []   []
# 14814  Sayang banget yaa padahal 2 episode terakhir i...       []   []
# 14815  @Dhewi_Dhewi @AmarFJKT48 Ayoo kakkk vc ama Fio...       []   []
# 14816  @ffarliani Tadi aku tanya bayu, katanya ngga p...       []   []
# 14817  Makasih minn seru banget malming inii 😭😭  #Day...       []   []
#
#                                                   photos  ...  \
# 0                                                     []  ...
# 1      [https://pbs.twimg.com/media/E3ASOpvVoAIE6UI.jpg]  ...
# 2                                                     []  ...
# 3                                                     []  ...
# 4      [https://pbs.twimg.com/media/E3AIRmZVIAQJigD.jpg]  ...
# ...                                                  ...  ...
# 14813                                                 []  ...
# 14814                                                 []  ...
# 14815                                                 []  ...
# 14816                                                 []  ...
# 14817  [https://pbs.twimg.com/media/E3IGLWTUUAEaNxR.jpg]  ...
#
#                                                quote_url  near  geo source  \
# 0
# 1
# 2
# 3      https://twitter.com/Abu_Ar_Rayyan/status/14005...
# 4
# ...                                                  ...   ...  ...    ...
# 14813
# 14814
# 14815
# 14816
# 14817
#
#       user_rt_id  user_rt retweet_id  \
# 0
# 1
# 2
# 3
# 4
# ...          ...      ...        ...
# 14813
# 14814
# 14815
# 14816
# 14817
#
#                                                 reply_to retweet_date Label
# 0      [{'screen_name': 'Taufik06644475', 'name': 'Ta...                 -1
# 1                                                     []                 -1
# 2      [{'screen_name': 'dahlia93362963', 'name': 'da...                 -1
# 3                                                     []                 -1
# 4      [{'screen_name': 'GoblokKadrun', 'name': 'Kadr...                 -1
# ...                                                  ...          ...   ...
# 14813                                                 []                  1
# 14814                                                 []                  1
# 14815  [{'screen_name': 'Dhewi_Dhewi', 'name': 'Dewi'...                  1
# 14816  [{'screen_name': 'ffarliani', 'name': 'feni', ...                  1
# 14817                                                 []                  1
#
# [14818 rows x 26 columns]

# %%
N, P = dataFinal.shape
'baris = ', N, ', Kolom = ', P
# Out:
# ('baris = ', 14817, ', Kolom = ', 27)

# %%
dataFinal.to_json('./NLP_Models/data/dataFinal.json', orient='records')

# %% [markdown]
# ### Cleaning Text

# %%
dataFinal.rename(columns={'tweet':'text'}, inplace=True)

# %%
dataFinal.keys()
# Out:
# Index(['created_at', 'date', 'time', 'user_id', 'username', 'name', 'text',
#        'mentions', 'urls', 'photos', 'replies_count', 'retweets_count',
#        'likes_count', 'hashtags', 'link', 'retweet', 'quote_url', 'near',
#        'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id', 'reply_to',
#        'retweet_date', 'Label'],
#       dtype='object')

# %%
dataFinal = ct.cleanningtext(data = dataFinal, both = True, onlyclean = False, sentiment = False)
# Out:
# Cleaning Text
# 100%|████████████████████████████████████████████████████████████████████████████| 14817/14817 [04:37<00:00, 53.32it/s]
# C:\Users\DEBBY ROBIYANTI\AI\NLP\NLP_Models\CleanText.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = data['text'].progress_apply(lambda x : tm.cleanText(x,fix=SlangS, pattern2 = True, lang = bahasa, lemma=lemmatizer, stops = stops, symbols_remove = True, numbers_remove = True, hashtag_remove=False, min_charLen = 2))
# 100%|████████████████████████████████████████████████████████████████████████| 14817/14817 [00:00<00:00, 116025.13it/s]
# C:\Users\DEBBY ROBIYANTI\AI\NLP\NLP_Models\CleanText.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = data['cleaned_text'].progress_apply(lambda x : tm.handlingnegation(x))
# 278.24197793006897 seconds

# %%
dataFinal.cleaned_text
# Out:
# 0        tolol berangkat haji negara negara mayoritas n...
# 1        setan kadrun politikus busuk tolol nkri lari b...
# 2        bipang year tolol permanen ngeyel karakter bip...
# 3        bipang year tolol permanen ngeyel viralin bodo...
# 4                makan bipang ambawang cebong goblok tolol
#                                ...
# 14813           seru banget gangguin mirae jyubi pakai gif
# 14814    sayang banget episode bagus banget anti klimas...
# 14815                 kakk fiony seru banget anaknya wkwkw
# 14816                                bayu nama seru banget
# 14817    makasih minn seru banget malming inii daysixti...
# Name: cleaned_text, Length: 14817, dtype: object

# %%
dataFinal.text
# Out:
# 0        @taufik06644475 @tijabar nah ini tolol yg bole...
# 1        biar setan, kadrun, politikus busuk &amp; peng...
# 2        @dahlia93362963 @abu_ar_rayyan @sukurwong @neg...
# 3        😂 bipang of the year udah tolol permanen ngeye...
# 4        @goblokkadrun @herlin_673yp @ari3pras @ferdina...
#                                ...
# 14813    seru banget gangguin mirae sama jyubi pake gif 😏😏
# 14814    sayang banget yaa padahal 2 episode terakhir i...
# 14815    @dhewi_dhewi @amarfjkt48 ayoo kakkk vc ama fio...
# 14816    @ffarliani tadi aku tanya bayu, katanya ngga p...
# 14817    makasih minn seru banget malming inii 😭😭  #day...
# Name: text, Length: 14817, dtype: object

# %%
dataFinal.to_json('./NLP_Models/data/dataFinalClean.json', orient='records')

# %%
#cleaning data hate speech
data = pd.read_json('./NLP_Models/data/dataHate.json')

# %%
data.rename(columns={'tweet':'text'}, inplace=True)

# %%
data = ct.cleanningtext(data, both = True, onlyclean = False, sentiment = False)
# Out:
# Cleaning Text
# 100%|██████████████████████████████████████████████████████████████████████████████| 8117/8117 [02:03<00:00, 65.47it/s]
# C:\Users\DEBBY ROBIYANTI\AI\NLP\NLP_Models\CleanText.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = data['text'].progress_apply(lambda x : tm.cleanText(x,fix=SlangS, pattern2 = True, lang = bahasa, lemma=lemmatizer, stops = stops, symbols_remove = True, numbers_remove = True, hashtag_remove=False, min_charLen = 2))
# 100%|██████████████████████████████████████████████████████████████████████████| 8117/8117 [00:00<00:00, 112658.10it/s]
# C:\Users\DEBBY ROBIYANTI\AI\NLP\NLP_Models\CleanText.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cleaned_text'] = data['cleaned_text'].progress_apply(lambda x : tm.handlingnegation(x))
# 124.22801971435547 seconds

# %%
data.to_json('./NLP_Models/data/dataHateClean.json', orient='records')
